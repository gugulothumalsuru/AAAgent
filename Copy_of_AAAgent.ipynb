# %% [markdown]
# <a href="https://colab.research.google.com/github/gugulothumalsuru/AAAgent/blob/main/Copy_of_AAAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-66657f8d-2afd-46eb-924a-260e07045931" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66657f8d-2afd-46eb-924a-260e07045931">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
# sample_data

# %%
# !unzip AAAgent-backend-database.zip
# Out:
# Archive:  AAAgent-backend-database.zip
#   inflating: RetrieveDocumentPatch.py
#   inflating: Service.py
#   inflating: session1-notes.txt
#   inflating: Config.py
#   inflating: DataIngestion.py
#   inflating: InitializeGDrive.py
#   inflating: InsertDocument.py
#   inflating: InstallOllamaCheckOrSetup.py
#   inflating: OllamaSupabaseIntegrationTest.py
#   inflating: RetrieveDocument.py

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# sample_data

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
# !pip install fastapi uvicorn langchain==0.1.16 chromadb==0.4.24 supabase pydantic requests
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.4 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.7/817.7 kB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.5/525.5 kB 32.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 50.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 70.9 MB/s eta 0:00:00
# ...

# %%
import fastapi
import langchain
import chromadb
print("all core libraries impoorted sucessfully")
# Out:
# all core libraries impoorted sucessfully

# %%
# !mv Service.py services.py

# %%
# !ls
# Out:
# AAAgent-backend-database.zip  OllamaSupabaseIntegrationTest.py
# Config.py		      RetrieveDocumentPatch.py
# DataIngestion.py	      RetrieveDocument.py
# InitializeGDrive.py	      sample_data
# InsertDocument.py	      services.py
# InstallOllamaCheckOrSetup.py  session1-notes.txt

# %%
# !sed -n '1,30p' OllamaSupabaseIntegrationTest.py
# Out:
# import services
# from langchain_core.documents import Document
#
# db_client = services.get_supabase_client()
# ai_service = services.MigrationAIService(db_client)
#
# # This will now use Ollama!
# ai_service.vector_store.add_documents([
#     Document(page_content="Testing Ollama integration with Supabase.", metadata={"source": "local"})
# ])
#
# print("Success! Ollama is now handling your vectors.")

# %%
import services
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/tmp/ipython-input-3489205945.py", line 1, in <cell line: 0>
#     import services
#
#   File "/content/services.py", line 1
#     %%writefile /content/drive/MyDrive/AAAgent_Backend/services.py
#     ^
# SyntaxError: invalid syntax

# %%
# %%writefile services.py
# Out:
# Overwriting services.py

# %%
# !sed -n '1,10p' services.py

# %%
import os
import requests
# or other normal python imports

# %%
# !python OllamaSupabaseIntegrationTest.py
# Out:
# Traceback (most recent call last):
#   File "/content/OllamaSupabaseIntegrationTest.py", line 4, in <module>
#     db_client = services.get_supabase_client()
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'services' has no attribute 'get_supabase_client'

# %%
# !sed -n '1,200p' services.py

# %%
# %%writefile services.py
from supabase import create_client, Client
import os

def get_supabase_client() -> Client:
    """
    Creates and returns a Supabase client using environment variables
    """
    supabase_url = os.environ.get("SUPABASE_URL")
    supabase_key = os.environ.get("SUPABASE_SERVICE_KEY")

    if not supabase_url or not supabase_key:
        raise ValueError("Supabase environment variables are not set")

    return create_client(supabase_url, supabase_key)
# Out:
# Overwriting services.py

# %%
# !sed -n '1,50p' services.py
# Out:
# from supabase import create_client, Client
# import os
#
# def get_supabase_client() -> Client:
#     """
#     Creates and returns a Supabase client using environment variables
#     """
#     supabase_url = os.environ.get("SUPABASE_URL")
#     supabase_key = os.environ.get("SUPABASE_SERVICE_KEY")
#
#     if not supabase_url or not supabase_key:
#         raise ValueError("Supabase environment variables are not set")
#
#     return create_client(supabase_url, supabase_key)

# %%
import os

# Supabase project URL
os.environ["SUPABASE_URL"] = "xqxfhtltiwrvvfsjtkyf"

# Secret (service role) key
os.environ["SUPABASE_SERVICE_KEY"] = "sb_secret_35s9l45xcsngzmgW5Xbg8Q_RCkh610R"

print("Supabase credentials set")
# Out:
# Supabase credentials set
